# %% [markdown]
# # pycheckers primitive legal move catalog
#
# One row per primitive legal move template for each side and piece type. This intentionally excludes multi-jump turns; jump chaining will be handled separately.

# %%
import pandas as pd

from pycheckers import primitive_move_catalog_df

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 240)
pd.set_option("display.max_colwidth", None)

# %%
moves = primitive_move_catalog_df()
print(f"primitive legal move rows: {len(moves)}")
list(moves.columns)

# %%
moves
